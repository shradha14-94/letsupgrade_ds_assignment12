# %%
import numpy as np
import pandas as pd
df=pd.DataFrame(np.random.randn(400,6),index=pd.date_range('2022-03-25',periods=400))
df
# Out:
#                    0         1         2         3         4         5
# 2022-03-25  1.578153  0.378102 -0.454553 -0.281214 -0.452121 -0.772839
# 2022-03-26 -0.557076  0.941386  0.546497 -0.970355  1.278513 -0.123271
# 2022-03-27 -0.629636 -2.210402  1.326586 -0.620563 -2.669826  2.131379
# 2022-03-28  0.105976 -0.571428  1.083075 -0.303561  0.024741  0.745817
# 2022-03-29  0.397236 -0.235328 -1.341762 -1.028879 -0.799409 -0.613691
# ...              ...       ...       ...       ...       ...       ...
# 2023-04-24  1.549908 -0.153018  1.350785  0.417338 -0.612120  0.616033
# 2023-04-25  1.106925 -0.380171 -0.456587 -0.697886  1.028773  0.966728
# 2023-04-26  2.012351 -0.176592 -0.460600 -0.130770 -1.473781 -0.634918
# 2023-04-27  0.677910  0.159506  2.470684  1.969954 -0.549058 -1.280393
# 2023-04-28  1.282134 -0.237142  0.930823 -1.052071  1.415861 -1.793327
#
# [400 rows x 6 columns]

# %%
df.plot(kind="line",figsize=(10,10))
# Out:
# <AxesSubplot:>
